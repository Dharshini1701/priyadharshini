# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
print("Rows and Columns:",df.shape)
# Out:
# Rows and Columns: (11500, 9)

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
print(df.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Content Rating', 'Last Updated'],
#       dtype='object')

# %%
import pandas as pd
df=pd.read_cs("google_playstore_2026-selected.csv")
print("Duplicated:",df.duplicated())
# Out:
# Duplicated: 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11495    False
# 11496    False
# 11497    False
# 11498    False
# 11499    False
# Length: 11500, dtype: bool

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
print(df["Category"].value_counts())
# Out:
# Category
# GAME                       2061
# FAMILY                     1763
# TOOLS                      1162
# PRODUCTIVITY                951
# ARTIFICIAL_INTELLIGENCE     823
# FINANCE                     721
# SOCIAL                      607
# PERSONALIZATION             146
# BOOKS_AND_REFERENCE         138
# SHOPPING                    133
# SPORTS                      132
# NEWS_AND_MAGAZINES          132
# VIDEO_PLAYERS               131
# MAPS_AND_NAVIGATION         131
# MEDICAL                     131
# HOUSE_AND_HOME              128
# WEATHER                     126
# PHOTOGRAPHY                 124
# AUTO_AND_VEHICLES           121
# TRAVEL_AND_LOCAL            115
# ENTERTAINMENT               114
# FOOD_AND_DRINK              114
# WEB3_AND_CRYPTO             114
# HEALTH_AND_FITNESS          113
# LIFESTYLE                   113
# COMICS                      112
# VIRTUAL_REALITY             111
# ART_AND_DESIGN              110
# BUSINESS                    110
# ...

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
top_rating=df.sort_values(by="Rating",ascending=False)
print(top_rating[["App","Category","Rating"]])
# Out:
#                    App                 Category  Rating
# 41         Browser Hub                     GAME     5.0
# 9686    Editor Go 2023                   FAMILY     5.0
# 6               Pay 3D  ARTIFICIAL_INTELLIGENCE     5.0
# 1384              Chat                     GAME     5.0
# 9595           Browser  ARTIFICIAL_INTELLIGENCE     5.0
# ...                ...                      ...     ...
# 11495  Epic Learn Plus             PRODUCTIVITY     NaN
# 11496      Scanner Pro              PHOTOGRAPHY     NaN
# 11497        Dash 2023                  WEATHER     NaN
# 11498       Pro Strike      BOOKS_AND_REFERENCE     NaN
# 11499           Health                  FINANCE     NaN
#
# [11500 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
d=df[(df["Rating"]>4.5)&(df["Reviews"]<1000)]
print(d[["App","Rating","Reviews"]])
# Out:
#                    App  Rating  Reviews
# 760            Tracker     4.8      884
# 762            Tracker     4.7      764
# 770        Tracker Pro     4.9      658
# 774   Epic Wallet 2024     4.6      602
# 776         Easy Craft     5.0      576
# ...                ...     ...      ...
# 9686    Editor Go 2023     5.0        5
# 9688    Pro Player Hub     5.0        5
# 9695  Epic Editor 2026     4.6        5
# 9699           Fit Pro     4.8        5
# 9703           Browser     4.6        5
#
# [1142 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
result=df.groupby("Type").agg(
  Total_Apps=("App","count"),
  Avg_Rating=("Rating","mean"),
  Avg_Reviews=("Reviews","mean")
  )
print(result)
# Out:
#       Total_Apps  Avg_Rating   Avg_Reviews
# Type
# Free       11027    4.058446   7883.015235
# Paid         473    4.028906  24117.323467

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
df.rename(columns={"Reviews":"Total_reviews",
                   "Installs":"Total_installs"},inplace=True)
print(df.columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Total_reviews', 'Size', 'Total_installs',
#        'Type', 'Content Rating', 'Last Updated'],
#       dtype='object')

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
result=df[df.isnull().any(axis=1)]
print(result)
# Out:
#                    App                 Category  Rating  Reviews  \
# 5313       Ultra Craft  ARTIFICIAL_INTELLIGENCE     NaN        4
# 5314           Tracker                   FAMILY     NaN        4
# 5315       Next Editor                     GAME     NaN        4
# 5316      Planner Plus             PRODUCTIVITY     NaN        4
# 5317   Super Player 3D          VIRTUAL_REALITY     NaN        4
# ...                ...                      ...     ...      ...
# 11495  Epic Learn Plus             PRODUCTIVITY     NaN        0
# 11496      Scanner Pro              PHOTOGRAPHY     NaN        0
# 11497        Dash 2023                  WEATHER     NaN        0
# 11498       Pro Strike      BOOKS_AND_REFERENCE     NaN        0
# 11499           Health                  FINANCE     NaN        0
#
#                      Size Installs  Type Content Rating        Last Updated
# 5313   Varies with device     500+  Free       Everyone        May 06, 2026
# ...

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
df.drop(columns=["Content Rating"],inplace=True)
print(df)
# Out:
#                    App             Category  Rating   Reviews  \
# 0          Strike Plus               FAMILY     4.6  12460594
# 1           Tracker AI            EDUCATION     3.4  11487705
# 2              Scanner               FAMILY     3.5  10503932
# 3           Connect 3D       ART_AND_DESIGN     4.7   4818860
# 4                  VPN         PRODUCTIVITY     3.5   3562800
# ...                ...                  ...     ...       ...
# 11495  Epic Learn Plus         PRODUCTIVITY     NaN         0
# 11496      Scanner Pro          PHOTOGRAPHY     NaN         0
# 11497        Dash 2023              WEATHER     NaN         0
# 11498       Pro Strike  BOOKS_AND_REFERENCE     NaN         0
# 11499           Health              FINANCE     NaN         0
#
#                      Size      Installs  Type        Last Updated
# 0      Varies with device  500,000,000+  Free    January 15, 2026
# 1      Varies with device  500,000,000+  Free    October 22, 2025
# ...

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
df["Rating"]=df["Rating"].fillna(
df["Rating"].mean())

print(df["Rating"].isnull().sum())
# Out:
# 0

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
df1=df.iloc[0:10]
print(df1)
# Out:
#            App                 Category  Rating   Reviews                Size  \
# 0  Strike Plus                   FAMILY     4.6  12460594  Varies with device
# 1   Tracker AI                EDUCATION     3.4  11487705  Varies with device
# 2      Scanner                   FAMILY     3.5  10503932  Varies with device
# 3   Connect 3D           ART_AND_DESIGN     4.7   4818860              221.6M
# 4          VPN             PRODUCTIVITY     3.5   3562800              122.9M
# 5      Planner           ART_AND_DESIGN     3.9   2432119              187.4M
# 6       Pay 3D  ARTIFICIAL_INTELLIGENCE     5.0   1473707               15.6M
# 7  Browser Now                  MEDICAL     4.2   1428040               80.1M
# 8   Player Max                    TOOLS     4.0    677625              134.0M
# 9    Quick Pay                   SOCIAL     3.8   2252646              127.5M
#
#        Installs  Type Content Rating        Last Updated
# ...

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
df1=df.loc[:,["App","Rating"]]
print(df1)
# Out:
#                    App  Rating
# 0          Strike Plus     4.6
# 1           Tracker AI     3.4
# 2              Scanner     3.5
# 3           Connect 3D     4.7
# 4                  VPN     3.5
# ...                ...     ...
# 11495  Epic Learn Plus     NaN
# 11496      Scanner Pro     NaN
# 11497        Dash 2023     NaN
# 11498       Pro Strike     NaN
# 11499           Health     NaN
#
# [11500 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_csv("google_playstore_2026-selected.csv")
latest=df.sort_values("Last Updated")
print(latest[["App","Last Updated"]].head(10))
# Out:
#                     App    Last Updated
# 7595         Tracker 3D  April 01, 2023
# 3382   Lite Player Plus  April 01, 2023
# 9818              Drive  April 01, 2023
# 10332            Fit 3D  April 01, 2024
# 9970     Crypto Scanner  April 01, 2024
# 3755   Daily Health Pro  April 01, 2024
# 8003            Connect  April 01, 2024
# 6568               Chat  April 01, 2025
# 1649          Craft App  April 01, 2025
# 1032           Epic Pay  April 01, 2025

# %%
import matplotlib.pyplot as plt
category_count = df["Category"].value_counts()

plt.figure(figsize=(10,5))

category_count.head(10).plot(
    kind="bar"
)

plt.title("Top 10 Categories by Number of Apps")
plt.xlabel("Category")
plt.ylabel("App Count")

plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10,6))

sns.histplot(
    df["Rating"].dropna(),
    bins=20,
    kde=True
)

plt.title("Distribution of App Ratings",
          fontsize=14)

plt.xlabel("Rating")
plt.ylabel("Number of Apps")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="Installs",
    y="Reviews",
    alpha=0.5
)

plt.title("Relationship Between Installs and Reviews")
plt.xlabel("Total Installs")
plt.ylabel("Total Reviews")

plt.xticks(rotation=45)

plt.show()
